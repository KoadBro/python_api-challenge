# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 588

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity'] 
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed'] 
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taihecun
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | college
# Processing Record 6 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 1 | mora
# Processing Record 8 of Set 1 | takehara
# Processing Record 9 of Set 1 | hami
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | carutapera
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | wad medani
# Processing Record 14 of Set 1 | alesund
# Processing Record 15 of Set 1 | al bardiyah
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | invercargill
# Processing Record 20 of Set 1 | tsiombe
# Processing Record 21 of Set 1 | badger
# Processing Record 22 of Set 1 | arteche
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | berala
# Processing Record 25 of Set 1 | acajutla
# Processing Record 26 of Set 1 | constitucion
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | olonkinbyen
# Processing Record 29 of Set 1 | stanley
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | san julian
# Processing Record 32 of Set 1 | port mathurin
# Processing Record 33 of Set 1 | port-aux-francais
# Processing Record 34 of Set 1 | waitangi
# Processing Record 35 of Set 1 | edinburgh of the seven seas
# Processing Record 36 of Set 1 | grytviken
# Processing Record 37 of Set 1 | praia da vitoria
# Processing Record 38 of Set 1 | bilibino
# Processing Record 39 of Set 1 | tolanaro
# Processing Record 40 of Set 1 | olgii
# City not found. Skipping...
# Processing Record 41 of Set 1 | afaahiti
# Processing Record 42 of Set 1 | agat village
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | kingston
# Processing Record 45 of Set 1 | graham
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | ulysses
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | papatowai
# Processing Record 0 of Set 2 | zapala
# Processing Record 1 of Set 2 | sisimiut
# Processing Record 2 of Set 2 | udachny
# Processing Record 3 of Set 2 | fonyod
# Processing Record 4 of Set 2 | rosso
# Processing Record 5 of Set 2 | saynshand
# Processing Record 6 of Set 2 | tambopata
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | aoulef
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | aasiaat
# Processing Record 11 of Set 2 | gadzhiyevo
# Processing Record 12 of Set 2 | kemijarvi
# Processing Record 13 of Set 2 | blackmans bay
# Processing Record 14 of Set 2 | port hedland
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | siwa oasis
# Processing Record 17 of Set 2 | xinpu
# Processing Record 18 of Set 2 | egilsstadir
# Processing Record 19 of Set 2 | kudahuvadhoo
# Processing Record 20 of Set 2 | betio village
# Processing Record 21 of Set 2 | natal
# Processing Record 22 of Set 2 | sinabang
# Processing Record 23 of Set 2 | sao gabriel da cachoeira
# Processing Record 24 of Set 2 | morehead
# Processing Record 25 of Set 2 | trairi
# Processing Record 26 of Set 2 | aleksandrovsk-sakhalinskiy
# Processing Record 27 of Set 2 | lihue
# Processing Record 28 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 2 | yaren
# Processing Record 30 of Set 2 | aswan
# Processing Record 31 of Set 2 | adam
# Processing Record 32 of Set 2 | guerrero negro
# Processing Record 33 of Set 2 | nishinoomote
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | hammerfest
# Processing Record 36 of Set 2 | xilin hot
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | jutai
# Processing Record 39 of Set 2 | sandnessjoen
# Processing Record 40 of Set 2 | medicine hat
# Processing Record 41 of Set 2 | am djarass
# City not found. Skipping...
# Processing Record 42 of Set 2 | laojunmiao
# Processing Record 43 of Set 2 | san salvador
# Processing Record 44 of Set 2 | atafu village
# Processing Record 45 of Set 2 | margaret river
# Processing Record 46 of Set 2 | hede
# Processing Record 47 of Set 2 | vetluzhskiy
# Processing Record 48 of Set 2 | peterborough
# Processing Record 49 of Set 2 | iqaluit
# Processing Record
of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 4 | west island
# Processing Record 29 of Set 4 | alpine
# Processing Record 30 of Set 4 | faya-largeau
# Processing Record 31 of Set 4 | songjiang
# Processing Record 32 of Set 4 | selfoss
# Processing Record 33 of Set 4 | sorong
# Processing Record 34 of Set 4 | kargasok
# Processing Record 35 of Set 4 | midvagur
# Processing Record 36 of Set 4 | sihanoukville
# Processing Record 37 of Set 4 | turinsk
# Processing Record 38 of Set 4 | fort bragg
# Processing Record 39 of Set 4 | rabo de peixe
# Processing Record 40 of Set 4 | modimolle
# Processing Record 41 of Set 4 | palmerston north
# Processing Record 42 of Set 4 | black river
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | vadso
# Processing Record 45 of Set 4 | kadipur
# Processing Record 46 of Set 4 | elliot lake
# Processing Record 47 of Set 4 | walvis bay
# Processing Record 48 of Set 4 | tabas
# Processing Record 49 of Set 4 | isafjordur
# Processing Record 0 of Set 5 | vilyuchinsk
# Processing Record 1 of Set 5 | vorgashor
# Processing Record 2 of Set 5 | anadyr
# Processing Record 3 of Set 5 | enewetak
# Processing Record 4 of Set 5 | stephenville
# Processing Record 5 of Set 5 | tazacorte
# Processing Record 6 of Set 5 | san sebastian de la gomera
# Processing Record 7 of Set 5 | la romana
# Processing Record 8 of Set 5 | georgetown
# Processing Record 9 of Set 5 | yugorsk
# Processing Record 10 of Set 5 | west plains
# Processing Record 11 of Set 5 | ocean shores
# Processing Record 12 of Set 5 | uturoa
# Processing Record 13 of Set 5 | nova sintra
# Processing Record 14 of Set 5 | gaspe
# Processing Record 15 of Set 5 | beyneu
# Processing Record 16 of Set 5 | dvurechensk
# Processing Record 17 of Set 5 | adilcevaz
# Processing Record 18 of Set 5 | cafayate
# Processing Record 19 of Set 5 | souillac
# Processing Record 20 of Set 5 | keflavik
# Processing Record 21 of Set 5 | chonchi
# Processing Record 22 of Set 5 | kilindoni
# Processing Record 23 of Set 5 | bumba
# Processing Record 24 of Set 5 | port elizabeth
# Processing Record 25 of Set 5 | khandyga
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | holualoa
# Processing Record 28 of Set 5 | coahuayana de hidalgo
# Processing Record 29 of Set 5 | leava
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | taltal
# Processing Record 32 of Set 5 | novodvinsk
# Processing Record 33 of Set 5 | carloforte
# Processing Record 34 of Set 5 | zhezqazghan
# Processing Record 35 of Set 5 | tutoia
# Processing Record 36 of Set 5 | beau vallon
# Processing Record 37 of Set 5 | ocean city
# Processing Record 38 of Set 5 | beaver falls
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | susuman
# Processing Record 41 of Set 5 | olinda
# Processing Record 42 of Set 5 | bamboo flat
# Processing Record 43 of Set 5 | ingeniero jacobacci
# Processing Record 44 of Set 5 | spanish wells
# Processing Record 45 of Set 5 | hamilton
# Processing Record 46 of Set 5 | tomatlan
# Processing Record 47 of Set 5 | boke
# Processing Record 48 of Set 5 | kuvshinovo
# Processing Record 49 of Set 5 | tralee
# Processing Record 0 of Set 6 | smithers
# Processing Record 1 of Set 6 | weno
# Processing Record 2 of Set 6 | queenstown
# Processing Record 3 of Set 6 | talnakh
# Processing Record 4 of Set 6 | caleta de carquin
# Processing Record 5 of Set 6 | mesquite
# Processing Record 6 of Set 6 | tyukhtet
# Processing Record 7 of Set 6 | katsuren-haebaru
# Processing Record 8 of Set 6 | cradock
# Processing Record 9 of Set 6 | keban
# Processing Record 10 of Set 6 | magadan
# Processing Record 11 of Set 6 | kadom
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | fernie
# Processing Record 14 of Set 6 | utrik
# Processing Record 15 of Set 6 | conceicao do araguaia
# Processing Record 16 of Set 6 | bargara
# City not found. Skipping...
# Processing Record 17 of Set 6 | gardez
# Processing Record 18 of Set 6 | mhamid
# Processing Record 19 of Set 6 | flin flon
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | es castell
# Processing Record 22 of Set 6 | tropea
# Processing Record 23 of Set 6 | salmon arm
# Processing Record 24 of Set 6 | al hasakah
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | satteldorf
# Processing Record 27 of Set 6 | koesan
# Processing Record 28 of Set 6 | aldinga beach
# Processing Record 29 of Set 6 | raduzhny
# Processing Record 30 of Set 6 | vredendal
# Processing Record 31 of Set 6 | thunder bay
# Processing Record 32 of Set 6 | hacienda huancane
# Processing Record 33 of Set 6 | ocean pointe
# City not found. Skipping...
# Processing Record 34 of Set 6 | greymouth
# Processing Record 35 of Set 6 | ust-nera
# Processing Record 36 of Set 6 | trancas
# Processing Record 37 of Set 6 | xai-xai
# Processing Record 38 of Set 6 | pyapon
# Processing Record 39 of Set 6 | willowmore
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | la almunia de dona godina
# Processing Record 42 of Set 6 | hithadhoo
# Processing Record 43 of Set 6 | kandyagash
# Processing Record 44 of Set 6 | nanpiao
# Processing Record 45 of Set 6 | bayevo
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | villa gesell
# Processing Record 48 of Set 6 | leua
# Processing Record 49 of Set 6 | onguday
# Processing Record 0 of Set 7 | crane
# Processing Record 1 of Set 7 | loreto
# Processing Record 2 of Set 7 | bonthe
# Processing Record 3 of Set 7 | soio
# Processing Record 4 of Set 7 | arraial do cabo
# Processing Record 5 of Set 7 | whitehorse
# Processing Record 6 of Set 7 | fang
# Processing Record 7 of Set 7 | svetlyy
# Processing Record 8 of Set 7 | kavaratti
# Processing Record 9 of Set 7 | nikel
# Processing Record 10 of Set 7 | codrington
# Processing Record 11 of Set 7 | marrakesh
# Processing Record 12 of Set 7 | malango
# Processing Record 13 of Set 7 | borinskoye
# Processing Record 14 of Set 7 | lagos de moreno
# Processing Record 15 of Set 7 | akureyri
# Processing Record 16 of Set 7 | de aar
# Processing Record 17 of Set 7 | broken hill
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 
# Processing Record 47 of Set 8 | vypasne
# Processing Record 48 of Set 8 | idabel
# Processing Record 49 of Set 8 | port alfred
# Processing Record 0 of Set 9 | grand falls-windsor
# Processing Record 1 of Set 9 | qamdo
# Processing Record 2 of Set 9 | sikasso
# Processing Record 3 of Set 9 | aykhal
# Processing Record 4 of Set 9 | torghay
# Processing Record 5 of Set 9 | tamandare
# Processing Record 6 of Set 9 | kristiansund
# Processing Record 7 of Set 9 | santa cruz
# Processing Record 8 of Set 9 | puerto san jose
# Processing Record 9 of Set 9 | asa
# Processing Record 10 of Set 9 | antofagasta
# Processing Record 11 of Set 9 | ambon
# Processing Record 12 of Set 9 | mana
# Processing Record 13 of Set 9 | san juan de miraflores
# Processing Record 14 of Set 9 | hashtpar
# Processing Record 15 of Set 9 | laikit, laikit ii (dimembe)
# Processing Record 16 of Set 9 | dadukou
# Processing Record 17 of Set 9 | arfoud
# Processing Record 18 of Set 9 | san antonio de pale
# Processing Record 19 of Set 9 | 'izbat al burj
# City not found. Skipping...
# Processing Record 20 of Set 9 | amahai
# Processing Record 21 of Set 9 | castillos
# Processing Record 22 of Set 9 | kinkala
# Processing Record 23 of Set 9 | hasaki
# Processing Record 24 of Set 9 | scottsburg
# Processing Record 25 of Set 9 | isla vista
# Processing Record 26 of Set 9 | papao
# Processing Record 27 of Set 9 | tangalle
# Processing Record 28 of Set 9 | puerto armuelles
# Processing Record 29 of Set 9 | pearsall
# Processing Record 30 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 31 of Set 9 | marquette
# Processing Record 32 of Set 9 | kalemie
# Processing Record 33 of Set 9 | mumbai
# Processing Record 34 of Set 9 | mildura
# Processing Record 35 of Set 9 | salalah
# Processing Record 36 of Set 9 | whistler
# Processing Record 37 of Set 9 | midelt
# Processing Record 38 of Set 9 | kribi
# Processing Record 39 of Set 9 | bishkul
# Processing Record 40 of Set 9 | bardai
# Processing Record 41 of Set 9 | copala
# Processing Record 42 of Set 9 | tenenkou
# Processing Record 43 of Set 9 | horta
# Processing Record 44 of Set 9 | isabela
# Processing Record 45 of Set 9 | cidreira
# Processing Record 46 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 9 | sao pedro do piaui
# Processing Record 48 of Set 9 | taoudenni
# Processing Record 49 of Set 9 | belyy yar
# Processing Record 0 of Set 10 | nadi
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | san borja
# Processing Record 3 of Set 10 | undurkhaan
# Processing Record 4 of Set 10 | aral
# Processing Record 5 of Set 10 | babruysk
# Processing Record 6 of Set 10 | merizo village
# Processing Record 7 of Set 10 | ashland
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | corn island
# Processing Record 10 of Set 10 | belmonte
# Processing Record 11 of Set 10 | gazojak
# Processing Record 12 of Set 10 | fraga
# Processing Record 13 of Set 10 | gislaved
# Processing Record 14 of Set 10 | camalu
# Processing Record 15 of Set 10 | kavali
# Processing Record 16 of Set 10 | sao vicente
# Processing Record 17 of Set 10 | tambacounda
# Processing Record 18 of Set 10 | plettenberg bay
# Processing Record 19 of Set 10 | altamira
# Processing Record 20 of Set 10 | yuza
# Processing Record 21 of Set 10 | iquitos
# Processing Record 22 of Set 10 | neiafu
# Processing Record 23 of Set 10 | klyuchi
# Processing Record 24 of Set 10 | veinticinco de mayo
# Processing Record 25 of Set 10 | kuanda
# Processing Record 26 of Set 10 | la'ie
# Processing Record 27 of Set 10 | midland
# Processing Record 28 of Set 10 | newman
# Processing Record 29 of Set 10 | taperoa
# Processing Record 30 of Set 10 | bir hadaj
# City not found. Skipping...
# Processing Record 31 of Set 10 | guaruja
# Processing Record 32 of Set 10 | labytnangi
# Processing Record 33 of Set 10 | campbellsville
# Processing Record 34 of Set 10 | saint-philippe
# Processing Record 35 of Set 10 | hovd
# Processing Record 36 of Set 10 | chililabombwe
# Processing Record 37 of Set 10 | macapa
# Processing Record 38 of Set 10 | chamzinka
# Processing Record 39 of Set 10 | nabire
# Processing Record 40 of Set 10 | paka
# Processing Record 41 of Set 10 | yopal
# Processing Record 42 of Set 10 | kone
# Processing Record 43 of Set 10 | hell-ville
# Processing Record 44 of Set 10 | balqash
# Processing Record 45 of Set 10 | el porvenir
# Processing Record 46 of Set 10 | asentamiento humano nicolas de pierola
# Processing Record 47 of Set 10 | campagnano di roma
# Processing Record 48 of Set 10 | ruteng
# Processing Record 49 of Set 10 | barrouallie
# Processing Record 0 of Set 11 | fortaleza
# Processing Record 1 of Set 11 | dubbo
# Processing Record 2 of Set 11 | arkhangel'sk
# Processing Record 3 of Set 11 | pathein
# Processing Record 4 of Set 11 | mejit
# Processing Record 5 of Set 11 | jiazi
# Processing Record 6 of Set 11 | vorkuta
# Processing Record 7 of Set 11 | bereznik
# Processing Record 8 of Set 11 | bayanhongor
# Processing Record 9 of Set 11 | okha
# Processing Record 10 of Set 11 | port augusta
# Processing Record 11 of Set 11 | puerto baquerizo moreno
# Processing Record 12 of Set 11 | akjoujt
# Processing Record 13 of Set 11 | arno
# Processing Record 14 of Set 11 | yazoo city
# Processing Record 15 of Set 11 | bemidji
# Processing Record 16 of Set 11 | vertientes
# Processing Record 17 of Set 11 | bulawayo
# Processing Record 18 of Set 11 | bathsheba
# Processing Record 19 of Set 11 | bodaybo
# Processing Record 20 of Set 11 | tobruk
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | ciudad bolivar
# Processing Record 23 of Set 11 | raichur
# Processing Record 24 of Set 11 | buurhakaba
# Processing Record 25 of Set 11 | broome
# Processing Record 26 of Set 11 | naracoorte
# Processing Record 27 of Set 11 | montecchio emilia
# Processing Record 28 of Set 11 | jaca
# Processing Record 29 of Set 11 | cadale
# Processing Record 30 of Set 11 | kembe
# Processing Record 31 of Set 11 | mcalester
# Processing Record 32 of Set 11 | kazanlak
# Processing Record 33 of Set 11 | cooma
# Processing Record 34 of Set 11 | valparaiso
# Processing Record 35 of Set 11 | aalborg
# Processing Record 36 of Set 11 | plainfield
# Processing Record 37 of Set 11 | camabatela
# Processing Record 38 of Set 11 | mawlamyinegyunn
# Processing Record 39 of Set 11 | kapit
# Processing Record 40 of Set 11 | la sarre
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | forster
# Processing Record 43 of Set 11 | lamu
# Processing Record 44 of Set 11 | enterprise
# Processing Record 45 of Set 11 | urengoy
# Processing Record 46 of Set 11 | makamba
# Processing Record 47 of Set 11 | tadine
# Processing Record 48 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 49 of Set 11 | howrah
# Processing Record 0 of Set 12 | beihai
# Processing Record 1 of Set 12 | larreynaga
# Processing Record 2 of Set 12 | kailua-kona
# Processing Record 3 of Set 12 | charters towers
# Processing Record 4 of Set 12 | mata-utu
# Processing Record 5 of Set 12 | veraval
# Processing Record 6 of Set 12 | barkhan
# Processing Record 7 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 8 of Set 12 | newport
# Processing Record 9 of Set 12 | namsos
# Processing Record 10 of Set 12 | albert
# Processing Record 11 of Set 12 | contamana
# Processing Record 12 of Set 12 | sabratah
# Processing Record 13 of Set 12 | el calafate
# Processing Record 14 of Set 12 | sainyabuli
# Processing Record 15 of Set 12 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 16 of Set 12 | east london
# Processing Record 17 of Set 12 | saudarkrokur
# Processing Record 18 of Set 12 | beichengqu
# Processing Record 19 of Set 12 | cestos city
# Processing Record 20 of Set 12 | corinto
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | los andes
# Processing Record 23 of Set 12 | sonsorol village
# City not found. Skipping...
# Processing Record 24 of Set 12 | usinsk
# Processing Record 25 of Set 12 | mayna
# Processing Record 26 of Set 12 | nuku'alofa
# Processing Record 27 of Set 12 | harper
# Processing Record 28 of Set 12 | praia
# Processing Record 29 of Set 12 | champerico
# Processing Record 30 of Set 12 | klaksvik
# Processing Record 31 of Set 12 | sauri
# Processing Record 32 of Set 12 | whakatane
# Processing Record 33 of Set 12 | magdagachi
# Processing Record 34 of Set 12 | cannonvale
# Processing Record 35 of Set 12 | lisala
# Processing Record 36 of Set 12 | moyale
# Processing Record 37 of Set 12 | pimentel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      taihecun  45.8000  130.8500     72.75        20         100
# 1        bethel  41.3712  -73.4140     62.47        72           0
# 2  puerto ayora  -0.7393  -90.3518     79.56        96          44
# 3      thompson  55.7435  -97.8558     51.96        62          20
# 4       college  64.8569 -147.8028     62.92        47          75
#
#    Wind Speed Country        Date
# 0       10.02      CN  1683862658
# 1        3.44      US  1683862616
# 2        7.00      EC  1683862477
# 3        8.05      CA  1683862616
# 4        8.05      US  1683862620

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            taihecun  45.8000  130.8500     72.75        20         100
# 1              bethel  41.3712  -73.4140     62.47        72           0
# 2        puerto ayora  -0.7393  -90.3518     79.56        96          44
# 3            thompson  55.7435  -97.8558     51.96        62          20
# 4             college  64.8569 -147.8028     62.92        47          75
#
#          Wind Speed Country        Date
# City_ID
# 0             10.02      CN  1683862658
# 1              3.44      US  1683862616
# 2              7.00      EC  1683862477
# 3              8.05      CA  1683862616
# 4              8.05      US  1683862620

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(8,6))
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, 
            marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(8,6))
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, 
            marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(8,6))
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, 
            marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(8,6))
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, 
            marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linreg_plots(x_values, y_values, y_label, title, fig_name):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = x_values * slope + intercept

    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

    plt.figure(figsize=(8,6))
    plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
    plt.plot(x_values, regress_values, "r-")
    
    plt.title(title + " (%s)" % time.strftime("%x"))
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.grid(True)
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")

    plt.savefig("output_data/" + fig_name + ".png")

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        taihecun  45.8000  130.8500     72.75        20         100
# 1          bethel  41.3712  -73.4140     62.47        72           0
# 3        thompson  55.7435  -97.8558     51.96        62          20
# 4         college  64.8569 -147.8028     62.92        47          75
# 5            mora  11.0461   14.1401     86.31        24          66
#
#          Wind Speed Country        Date
# City_ID
# 0             10.02      CN  1683862658
# 1              3.44      US  1683862616
# 3              8.05      CA  1683862616
# 4              8.05      US  1683862620
# 5              1.21      CM  1683862658

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        puerto ayora  -0.7393  -90.3518     79.56        96          44
# 8          carutapera  -1.1950  -46.0200     76.15        93          23
# 13          adamstown -25.0660 -130.1015     72.10        60         100
# 14            ushuaia -54.8000  -68.3000     51.46        54          75
# 16       invercargill -46.4000  168.3500     53.35        79          83
#
#          Wind Speed Country        Date
# City_ID
# 2              7.00      EC  1683862477
# 8              4.09      BR  1683862635
# 13            16.91      PN  1683862616
# 14             3.44      AR  1683862326
# 16             8.68      NZ  1683862616

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

create_linreg_plots(x_values, y_values, "Max Temperature (F)", "Northern Hemisphere - Max Temp vs. Latitude Linear Regression", "NorthHemi_Temp_vs_Lat")

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

create_linreg_plots(x_values, y_values, "Max Temperature (F)", "Southern Hemisphere - Max Temp vs. Latitude Linear Regression", "SouthHemi_Temp_vs_Lat")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

create_linreg_plots(x_values, y_values, "Humidity (%)", "Northern Hemisphere - Humidity vs. Latitude Linear Regression", "NorthHemi_Humidity_vs_Lat")

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

create_linreg_plots(x_values, y_values, "Humidity (%)", "Southern Hemisphere - Humidity vs. Latitude Linear Regression", "SouthHemi_Humidity_vs_Lat")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

create_linreg_plots(x_values, y_values, "Cloudiness (%)", "Northern Hemisphere - Cloudiness vs. Latitude Linear Regression", "NorthHemi_Cloudiness_vs_Lat")

# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

create_linreg_plots(x_values, y_values, "Cloudiness (%)", "Southern Hemisphere - Cloudiness vs. Latitude Linear Regression", "SouthHemi_Cloudiness_vs_Lat")

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

create_linreg_plots(x_values, y_values, "Wind Speed (mph)", "Southern Hemisphere - Wind Speed vs. Latitude Linear Regression", "SouthHemi_WindSpeed_vs_Lat")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

create_linreg_plots(x_values, y_values, "Wind Speed (mph)", "Northern Hemisphere - Wind Speed vs. Latitude Linear Regression", "NorthHemi_WindSpeed_vs_Lat")

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

create_linreg_plots(x_values, y_values, "Humidity (%)", "Southern Hemisphere - Humidity vs. Latitude Linear Regression", "SouthHemi_Humidity_vs_Lat")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
